# %% [markdown]
# <a href="https://colab.research.google.com/github/jabarcamu/EDA_Practica4/blob/branch-piero/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q kaggle

# %%
# desde la cuenta de kaggle ir a generar api de acceso
# https://www.kaggle.com/general/74235
# https://stackoverflow.com/questions/49310470/using-kaggle-datasets-in-google-colab

from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-2e26099c-7bca-4342-b2c4-98ace3b64ab2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e26099c-7bca-4342-b2c4-98ace3b64ab2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"jpieroabarcam","key":"8885ba6ad255781124dd53b573cdb5b6"}'}

# %%
 ! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
 ! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              234KB  2021-07-15 20:26:37           9268
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           5672
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           2058
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   2GB  2021-07-03 18:37:20           2410
# promptcloud/careerbuilder-job-listing-2020                  Careerbuilder Job Listing 2020                     42MB  2021-03-05 06:59:52           1365
# nickuzmenkov/nih-chest-xrays-tfrecords                      NIH Chest X-rays TFRecords                         11GB  2021-03-09 04:49:23            759
# fatiimaezzahra/famous-iconic-women                          Famous Iconic Women                               838MB  2021-02-28 14:56:00            954
# coloradokb/dandelionimages                                  DandelionImages                                     4GB  2021-02-19 20:03:47            682
# alsgroup/end-als                                            End ALS Kaggle Challenge                           12GB  2021-04-08 12:16:37            788
# mathurinache/twitter-edge-nodes                             Twitter Edge Nodes                                342MB  2021-03-08 06:43:04            637
# simiotic/github-code-snippets                               GitHub Code Snippets                                7GB  2021-03-03 11:34:39            225
# landrykezebou/lvzhdr-tone-mapping-benchmark-dataset-tmonet  LVZ-HDR Tone Mapping Benchmark Dataset (TMO-Net)   24GB  2021-03-01 05:03:40            154
# mathurinache/the-lj-speech-dataset                          The LJ Speech Dataset                               3GB  2021-02-15 09:19:54            236
# imsparsh/accentdb-core-extended                             AccentDB - Core & Extended                          6GB  2021-02-17 14:22:54             92
# stuartjames/lights                                          LightS: Light Specularity Dataset                  18GB  2021-02-18 14:32:26             90
# nickuzmenkov/ranzcr-clip-kfold-tfrecords                    RANZCR CLiP KFold TFRecords                         2GB  2021-02-21 13:29:51            102
# datasnaek/youtube-new                                       Trending YouTube Video Statistics                 201MB  2019-06-03 00:56:47         144633
# zynicide/wine-reviews                                       Wine Reviews                                       51MB  2017-11-27 17:08:04         140202
# residentmario/ramen-ratings                                 Ramen Ratings                                      40KB  2018-01-11 16:04:39          24912
# datasnaek/chess                                             Chess Game Dataset (Lichess)                        3MB  2017-09-04 03:09:09          19941

# %%
! kaggle datasets download -d amjaads/netflix-movies
# Out:
# Downloading netflix-movies.zip to /content
#   0% 0.00/308k [00:00<?, ?B/s]
# 100% 308k/308k [00:00<00:00, 41.4MB/s]

# %%
! mkdir netflix

# %%
! unzip netflix-movies.zip -d netflix

# %%
# %cd netflix/
! ls
# Out:
# /content/netflix
# Netflix_movies.csv

# %%
import pandas as pd
data = pd.read_csv("Netflix_movies.csv")

# %%
data.head()
# Out:
#    Unnamed: 0           movie_name  ...  rating   enter_in_netflix
# 0           1    #FriendButMarried  ...     7.0       May 21, 2020
# 1           4              #Selfie  ...     6.1       June 1, 2019
# 2           5           #Selfie 69  ...     6.3       June 1, 2019
# 3           7         #realityhigh  ...     5.2  September 8, 2017
# 4           9  10 Days in Sun City  ...     5.3   October 18, 2019
#
# [5 rows x 10 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

#nombre = data["movie_name"]
genre = data["genre"]
country = data["country"]

#print(type(duration))


CountVec = CountVectorizer(ngram_range=(1,1), # to use bigrams ngram_range=(2,2)
                           stop_words='english',
                           encoding='utf-8')

CountVec2 = CountVectorizer(ngram_range=(1,1), # to use bigrams ngram_range=(2,2)
                           stop_words='english',
                           encoding='utf-8')

#transform
#Count_data = CountVec.fit_transform([sentence_1,sentence_2])
#Count_data1 = CountVec2.fit_transform(nombre)
#create dataframe descartado xxxxx
#cv_dataframe1=pd.DataFrame(Count_data1.toarray(),columns=CountVec2.get_feature_names())
#print(cv_dataframe1)


# resultados
Count_data2 = CountVec.fit_transform(genre)
genero=pd.DataFrame(Count_data2.toarray(),columns=CountVec.get_feature_names())

Count_data3 = CountVec.fit_transform(country)
pais=pd.DataFrame(Count_data3.toarray(),columns=CountVec.get_feature_names())


duration = data["Duration"]
year = data["year"]
rating = data["rating"]

desired_colums = data[["Duration", "year", "rating"]]
name = data[["movie_name"]]

juntartodo =  pd.concat([desired_colums, genero, pais, name], axis=1)


juntartodo.head()

#movies = [duration,year,rating,cv_dataframe2,cv_dataframe3]

#result = pd.concat(movies)
#result
# Out:
#    Duration  year  rating  action  ...  west  zealand  zimbabwe           movie_name
# 0       102  2018     7.0       0  ...     0        0         0    #FriendButMarried
# 1       125  2014     6.1       0  ...     0        0         0              #Selfie
# 2       119  2016     6.3       0  ...     0        0         0           #Selfie 69
# 3        99  2017     5.2       0  ...     0        0         0         #realityhigh
# 4        87  2017     5.3       0  ...     0        0         0  10 Days in Sun City
#
# [5 rows x 133 columns]

# %%
juntartodo


# data de entrenamimento
train = juntartodo[:3000]
#train.to_csv(index=False)
train.to_csv('train.csv', sep=',',encoding='utf-8', index=False)


# data de test
test = juntartodo[3001:]
test.to_csv('test.csv', sep=',',encoding='utf-8', index=False)

# %%
from google.colab import files

files.download('train.csv')
files.download('test.csv') 

pruebas =  pd.read_csv("train.csv")
pruebas

test =  pd.read_csv("test.csv")
test
# Out:
#      Duration  year  rating  ...  zealand  zimbabwe                    movie_name
# 0          94  2016     6.5  ...        0         0               Theater of Life
# 1         104  2017     6.5  ...        0         0                       Theeram
# 2         132  2013     6.1  ...        0         0  Theeya Velai Seyyanum Kumaru
# 3          67  2016     5.6  ...        0         0          Theo Von: No Offense
# 4         158  2007     8.2  ...        0         0           There Will Be Blood
# ..        ...   ...     ...  ...      ...       ...                           ...
# 317       128  2018     7.3  ...        0         0                  ​Goli Soda 2
# 318       117  2017     7.0  ...        0         0            ​Maj Rati ​​Keteki
# 319       100  2017     7.1  ...        0         0                   ​Mayurakshi
# 320       110  2018     7.5  ...        0         0          ​​Kuch Bheege Alfaaz
# 321       110  2017     6.5  ...        0         0                       반드시 잡는다
#
# [322 rows x 133 columns]

# %%
# Out:
#      Unnamed: 0                    movie_name  ...  zealand  zimbabwe
# 0          3001               Theater of Life  ...        0         0
# 1          3002                       Theeram  ...        0         0
# 2          3003  Theeya Velai Seyyanum Kumaru  ...        0         0
# 3          3004          Theo Von: No Offense  ...        0         0
# 4          3005           There Will Be Blood  ...        0         0
# ..          ...                           ...  ...      ...       ...
# 317        3318                  ​Goli Soda 2  ...        0         0
# 318        3319            ​Maj Rati ​​Keteki  ...        0         0
# 319        3320                   ​Mayurakshi  ...        0         0
# 320        3321          ​​Kuch Bheege Alfaaz  ...        0         0
# 321        3322                       반드시 잡는다  ...        0         0
#
# [322 rows x 134 columns]
